# %%
import pandas as pd

# 파일 불러오기
data = pd.read_csv('match_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0        date               title         stage          team1  \
# 0           0  2021.08.29  2021 LCK 서머 포스트 시즌       결승전 4세트             T1
# 1           1  2021.08.29  2021 LCK 서머 포스트 시즌       결승전 3세트             T1
# 2           2  2021.08.29  2021 LCK 서머 포스트 시즌       결승전 2세트        DWG KIA
# 3           3  2021.08.29  2021 LCK 서머 포스트 시즌       결승전 1세트        DWG KIA
# 4           4  2021.08.22  2021 LCK 서머 포스트 시즌  2라운드 2경기 4세트  Gen.G eSports
#
#      team2 win        top1        jg1          mid1         adc1      sup1  \
# 0  DWG KIA   L    T1 Canna    T1 Oner      T1 Faker  T1 Gumayusi  T1 Keria
# 1  DWG KIA   W    T1 Canna    T1 Oner      T1 Faker  T1 Gumayusi  T1 Keria
# 2       T1   W     DK Khan  DK Canyon  DK ShowMaker     DK Ghost  DK BeryL
# 3       T1   W     DK Khan  DK Canyon  DK ShowMaker     DK Ghost  DK BeryL
# 4       T1   L  GEN Rascal   GEN Clid       GEN BDD    GEN Ruler  GEN Life
#
#        top2        jg2          mid2      adc2      sup2
# 0   DK Khan  DK Canyon  DK ShowMaker  DK Ghost  DK BeryL
# 1   DK Khan  DK Canyon  DK ShowMaker  DK Ghost  DK BeryL
# 2  T1 Canna    T1 Oner      T1 Faker  T1 Teddy  T1 Keria
# 3  T1 Canna    T1 Oner      T1 Faker  T1 Teddy  T1 Keria
# 4  T1 Canna    T1 Oner      T1 Faker  T1 Teddy  T1 Keria

# %%
len(data)
# Out:
# 477

# %%
# 컬럼 수정 & 생성

data['stage'] = data['stage'].apply(lambda x :x[:-4])  # '0세트' 제거
data['point1'] = 0   # point1, point2 컬럼 생성
data['point2'] = 0

# %%
# 경기당 세트 수 카운트

set_count = data.groupby(['title','stage']).date.count().reset_index()
set_count
# Out:
#                            title     stage  date
# 0             2021 LCK 서머 포스트 시즌  1라운드 1경기     4
# 1             2021 LCK 서머 포스트 시즌  1라운드 2경기     3
# 2             2021 LCK 서머 포스트 시즌  2라운드 1경기     3
# 3             2021 LCK 서머 포스트 시즌  2라운드 2경기     4
# 4             2021 LCK 서머 포스트 시즌       결승전     4
# ..                           ...       ...   ...
# 185  2021 LoL 챔피언스 코리아 스프링 정규 시즌   7일차 2경기     2
# 186  2021 LoL 챔피언스 코리아 스프링 정규 시즌   8일차 1경기     3
# 187  2021 LoL 챔피언스 코리아 스프링 정규 시즌   8일차 2경기     3
# 188  2021 LoL 챔피언스 코리아 스프링 정규 시즌   9일차 1경기     2
# 189  2021 LoL 챔피언스 코리아 스프링 정규 시즌   9일차 2경기     2
#
# [190 rows x 3 columns]

# %%
# 이렇게 했어도 됐었ㅅ구나,,,^^;;;

data.drop_duplicates(['title','stage'], keep = 'first')
# Out:
#      Unnamed: 0        date                        title     stage  \
# 0             0  2021.08.29           2021 LCK 서머 포스트 시즌       결승전
# 4             4  2021.08.22           2021 LCK 서머 포스트 시즌  2라운드 2경기
# 8             8  2021.08.21           2021 LCK 서머 포스트 시즌  2라운드 1경기
# 11           11  2021.08.19           2021 LCK 서머 포스트 시즌  1라운드 2경기
# 14           14  2021.08.18           2021 LCK 서머 포스트 시즌  1라운드 1경기
# ..          ...         ...                          ...       ...
# 464         464  2021.01.15  2021 LoL 챔피언스 코리아 스프링 정규 시즌   3일차 1경기
# 466         466  2021.01.14  2021 LoL 챔피언스 코리아 스프링 정규 시즌   2일차 2경기
# 469         469  2021.01.14  2021 LoL 챔피언스 코리아 스프링 정규 시즌   2일차 1경기
# 472         472  2021.01.13  2021 LoL 챔피언스 코리아 스프링 정규 시즌   1일차 2경기
# 475         475  2021.01.13  2021 LoL 챔피언스 코리아 스프링 정규 시즌   1일차 1경기
#
#               team1                team2 win        top1         jg1  \
# 0                T1              DWG KIA   L    T1 Canna     T1 Oner
# 4     Gen.G eSports                   T1   L  GEN Rascal    GEN Clid
# 8      NS RED FORCE              DWG KIA   L     NS Rich   NS Peanut
# 11     Liiv Sandbox                   T1   L  LSB Summit   LSB Croco
# 14   Afreeca Freecs         NS RED FORCE   L     AF Kiin    AF Dread
# ..              ...                  ...  ..         ...         ...
# 464   Gen.G eSports         Fredit BRION   W  GEN Rascal    GEN Clid
# 466             DRX       Afreeca Freecs   W  DRX Kingen  DRX Pyosik
# 469    NS RED FORCE         Liiv Sandbox   W     NS Rich   NS Peanut
# 472              T1  Hanwha Life Esports   W    T1 Canna    T1 Ellim
# 475      kt Rolster        Gen.G eSports   L    KT Doran   KT Bonnie
#
#           mid1         adc1        sup1        top2         jg2          mid2  \
# 0     T1 Faker  T1 Gumayusi    T1 Keria     DK Khan   DK Canyon  DK ShowMaker
# 4      GEN BDD    GEN Ruler    GEN Life    T1 Canna     T1 Oner      T1 Faker
# 8      NS Gori   NS deokdam   NS Kellin     DK Khan   DK Canyon  DK ShowMaker
# 11    LSB Fate   LSB Prince  LSB Effort    T1 Canna     T1 Oner      T1 Faker
# 14      AF Fly       AF Leo  AF Lehends     NS Rich   NS Peanut       NS Gori
# ..         ...          ...         ...         ...         ...           ...
# 464    GEN BDD    GEN Ruler    GEN Life    BRO Hoya    BRO UmTi      BRO Lava
# 466  DRX SOLKA      DRX BAO   DRX Becca     AF Kiin    AF Dread        AF Fly
# 469     NS Bay   NS deokdam   NS Kellin  LSB Summit   LSB Croco      LSB Fate
# 472  T1 Clozer  T1 Gumayusi    T1 Keria  HLE Morgan  HLE Arthur     HLE Chovy
# 475    KT Ucal    KT HyBrid     KT Zzus  GEN Rascal    GEN Clid       GEN BDD
#
#            adc2         sup2  point1  point2
# 0      DK Ghost     DK BeryL       0       0
# 4      T1 Teddy     T1 Keria       0       0
# 8      DK Ghost     DK BeryL       0       0
# 11     T1 Teddy     T1 Keria       0       0
# 14   NS deokdam    NS Kellin       0       0
# ..          ...          ...     ...     ...
# 464    BRO Hena  BRO Delight       0       0
# 466     AF Bang   AF Lehends       0       0
# 469   LSB Route   LSB Effort       0       0
# 472    HLE Deft     HLE Vsta       0       0
# 475   GEN Ruler     GEN Life       0       0
#
# [190 rows x 19 columns]

# %%
set_count.date.unique()
# Out:
# array([4, 3, 5, 2], dtype=int64)

# %%
set_count.loc[(match_count.title=='2021 LCK 서머 포스트 시즌') & (match_count.stage=='1라운드 1경기'),'date'].values[0]
# Out:
# 4

# %%
# 몇대몇인지 계산

index = 0
for i in range(len(set_count)):
    team = data.loc[index,'team1']
    title = data.loc[index,'title']
    stage = data.loc[index,'stage']
    count = int(set_count.loc[(set_count.title==title) & (set_count.stage==stage),'date'].values[0])
    for j in range(count):
        if data.loc[index+j,'team1'] == team :
            if data.loc[index+j,'win'] == 'W':
                data.loc[index,'point1'] += 1
            else:
                data.loc[index,'point2'] += 1
        else:
            if data.loc[index+j,'win'] == 'W':
                data.loc[index,'point2'] += 1
            else:
                data.loc[index,'point1'] += 1
    #print(team, title, stage, count, index)
        
    index += count

# %%
# 첫번째 데이터만 남김

data = data[(data.point1!=0)|(data.point2!=0)]
data
# Out:
#      Unnamed: 0        date                        title     stage  \
# 0             0  2021.08.29           2021 LCK 서머 포스트 시즌       결승전
# 4             4  2021.08.22           2021 LCK 서머 포스트 시즌  2라운드 2경기
# 8             8  2021.08.21           2021 LCK 서머 포스트 시즌  2라운드 1경기
# 11           11  2021.08.19           2021 LCK 서머 포스트 시즌  1라운드 2경기
# 14           14  2021.08.18           2021 LCK 서머 포스트 시즌  1라운드 1경기
# ..          ...         ...                          ...       ...
# 464         464  2021.01.15  2021 LoL 챔피언스 코리아 스프링 정규 시즌   3일차 1경기
# 466         466  2021.01.14  2021 LoL 챔피언스 코리아 스프링 정규 시즌   2일차 2경기
# 469         469  2021.01.14  2021 LoL 챔피언스 코리아 스프링 정규 시즌   2일차 1경기
# 472         472  2021.01.13  2021 LoL 챔피언스 코리아 스프링 정규 시즌   1일차 2경기
# 475         475  2021.01.13  2021 LoL 챔피언스 코리아 스프링 정규 시즌   1일차 1경기
#
#               team1                team2 win        top1         jg1  \
# 0                T1              DWG KIA   L    T1 Canna     T1 Oner
# 4     Gen.G eSports                   T1   L  GEN Rascal    GEN Clid
# 8      NS RED FORCE              DWG KIA   L     NS Rich   NS Peanut
# 11     Liiv Sandbox                   T1   L  LSB Summit   LSB Croco
# 14   Afreeca Freecs         NS RED FORCE   L     AF Kiin    AF Dread
# ..              ...                  ...  ..         ...         ...
# 464   Gen.G eSports         Fredit BRION   W  GEN Rascal    GEN Clid
# 466             DRX       Afreeca Freecs   W  DRX Kingen  DRX Pyosik
# 469    NS RED FORCE         Liiv Sandbox   W     NS Rich   NS Peanut
# 472              T1  Hanwha Life Esports   W    T1 Canna    T1 Ellim
# 475      kt Rolster        Gen.G eSports   L    KT Doran   KT Bonnie
#
#           mid1         adc1        sup1        top2         jg2          mid2  \
# 0     T1 Faker  T1 Gumayusi    T1 Keria     DK Khan   DK Canyon  DK ShowMaker
# 4      GEN BDD    GEN Ruler    GEN Life    T1 Canna     T1 Oner      T1 Faker
# 8      NS Gori   NS deokdam   NS Kellin     DK Khan   DK Canyon  DK ShowMaker
# 11    LSB Fate   LSB Prince  LSB Effort    T1 Canna     T1 Oner      T1 Faker
# 14      AF Fly       AF Leo  AF Lehends     NS Rich   NS Peanut       NS Gori
# ..         ...          ...         ...         ...         ...           ...
# 464    GEN BDD    GEN Ruler    GEN Life    BRO Hoya    BRO UmTi      BRO Lava
# 466  DRX SOLKA      DRX BAO   DRX Becca     AF Kiin    AF Dread        AF Fly
# 469     NS Bay   NS deokdam   NS Kellin  LSB Summit   LSB Croco      LSB Fate
# 472  T1 Clozer  T1 Gumayusi    T1 Keria  HLE Morgan  HLE Arthur     HLE Chovy
# 475    KT Ucal    KT HyBrid     KT Zzus  GEN Rascal    GEN Clid       GEN BDD
#
#            adc2         sup2  point1  point2
# 0      DK Ghost     DK BeryL       1       3
# 4      T1 Teddy     T1 Keria       1       3
# 8      DK Ghost     DK BeryL       0       3
# 11     T1 Teddy     T1 Keria       0       3
# 14   NS deokdam    NS Kellin       1       3
# ..          ...          ...     ...     ...
# 464    BRO Hena  BRO Delight       2       0
# 466     AF Bang   AF Lehends       2       1
# 469   LSB Route   LSB Effort       2       1
# 472    HLE Deft     HLE Vsta       2       1
# 475   GEN Ruler     GEN Life       0       2
#
# [190 rows x 19 columns]

# %%
# hdfs에 저장하기

import findspark

findspark.init()

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# <ipython-input-209-52cbc3e47a46> in <module>
#       2 from pyspark.sql import SparkSession
#       3
# ----> 4 spark = SparkSession.builder.getOrCreate()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyspark\sql\session.py in getOrCreate(self)
#     226                             sparkConf.set(key, value)
#     227                         # This SparkContext may be an existing one.
# --> 228                         sc = SparkContext.getOrCreate(sparkConf)
#     229                     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     230                     # by all sessions.
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyspark\context.py in getOrCreate(cls, conf)
#     390         with SparkContext._lock:
#     391             if SparkContext._active_spark_context is None:
# --> 392                 SparkContext(conf=conf or SparkConf())
#     393             return SparkContext._active_spark_context
#     394
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyspark\context.py in __init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)
#     144         SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     145         try:
# --> 146             self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#     147                           conf, jsc, profiler_cls)
#     148         except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyspark\context.py in _do_init(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, jsc, profiler_cls)
#     224         self._encryption_enabled = self._jvm.PythonUtils.isEncryptionEnabled(self._jsc)
#     225         os.environ["SPARK_AUTH_SOCKET_TIMEOUT"] = \
# --> 226             str(self._jvm.PythonUtils.getPythonAuthSocketTimeout(self._jsc))
#     227         os.environ["SPARK_BUFFER_SIZE"] = \
#     228             str(self._jvm.PythonUtils.getSparkBufferSize(self._jsc))
#
# C:\ProgramData\Anaconda3\lib\site-packages\py4j\java_gateway.py in __getattr__(self, name)
#    1545                     answer, self._gateway_client, self._fqn, name)
#    1546         else:
# -> 1547             raise Py4JError(
#    1548                 "{0}.{1} does not exist in the JVM".format(self._fqn, name))
#    1549
#
# Py4JError: org.apache.spark.api.python.PythonUtils.getPythonAuthSocketTimeout does not exist in the JVM

# %%
df = spark.createDataFrame(data)
df
